# %%
from vector_drawing import *

# %%
vectors = [(x, x**2) for x in range(-10, 11, 1)]

draw(
    Points(*vectors),
    grid=(1,10),
    nice_aspect_ratio=False
)

# 

# print(points)

# draw(points, polygon)
